# %% [markdown]
# <a href="https://colab.research.google.com/github/dani3l-ruiizp/Entregables_2/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Pandas .csv")
df
# Out:
#               FECHA DE INICIO              FECHA FINAL  \
# 0     2024 Jan 01 12:00:00 AM  2024 Jan 01 12:00:00 AM
# 1     2024 Jan 01 12:00:00 AM  2024 Jan 02 12:00:00 AM
# 2     2024 Jan 01 12:00:00 AM  2024 Jan 03 12:00:00 AM
# 3     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM
# 4     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM
# ...                       ...                      ...
# 1853  2024 Dec 12 12:00:00 AM  2024 Dec 12 12:00:00 AM
# 1854  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1855  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1856  2024 Dec 25 12:00:00 AM  2024 Dec 25 12:00:00 AM
# 1857  2024 Dec 30 12:00:00 AM  2024 Dec 30 12:00:00 AM
#
#                                            DEPARTAMENTO            MUNICIPIO  \
# 0                                       VALLE DEL CAUCA                 CALI
# 1                                          CUNDINAMARCA                 NILO
# ...

# %%
df.tail()
# Out:
#               FECHA DE INICIO              FECHA FINAL  \
# 1853  2024 Dec 12 12:00:00 AM  2024 Dec 12 12:00:00 AM
# 1854  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1855  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1856  2024 Dec 25 12:00:00 AM  2024 Dec 25 12:00:00 AM
# 1857  2024 Dec 30 12:00:00 AM  2024 Dec 30 12:00:00 AM
#
#                                            DEPARTAMENTO            MUNICIPIO  \
# 1853                                              SUCRE              SAMPUES
# 1854                                              SUCRE  SAN JUAN DE BETULIA
# 1855                                            CÓRDOBA           SAN ANTERO
# 1856  ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANT...          PROVIDENCIA
# 1857                                            CAQUETÁ               SOLANO
#
#                  FUERZA O ENTIDAD ENTIDAD VINCULADA  \
# 1853  ARMADA NACIONAL DE COLOMBIA               NaN
# 1854  ARMADA NACIONAL DE COLOMBIA               NaN
# ...

# %%
df.head()
# Out:
#            FECHA DE INICIO              FECHA FINAL     DEPARTAMENTO  \
# 0  2024 Jan 01 12:00:00 AM  2024 Jan 01 12:00:00 AM  VALLE DEL CAUCA
# 1  2024 Jan 01 12:00:00 AM  2024 Jan 02 12:00:00 AM     CUNDINAMARCA
# 2  2024 Jan 01 12:00:00 AM  2024 Jan 03 12:00:00 AM        ANTIOQUIA
# 3  2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM  VALLE DEL CAUCA
# 4  2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM        SANTANDER
#
#      MUNICIPIO   FUERZA O ENTIDAD    ENTIDAD VINCULADA  \
# 0         CALI  EJÉRCITO NACIONAL  ENTIDADES DEL SNGRD
# 1         NILO  EJÉRCITO NACIONAL  ENTIDADES DEL SNGRD
# 2     MEDELLÍN  EJÉRCITO NACIONAL  ENTIDADES DEL SNGRD
# 3         CALI  EJÉRCITO NACIONAL  ENTIDADES DEL SNGRD
# 4  BUCARAMANGA  EJÉRCITO NACIONAL  ENTIDADES DEL SNGRD
#
#   PROCESO DE GESTIÓN DEL RIESGO                ACTIVIDAD REALIZADA  \
# 0          REDUCCIÓN DEL RIESGO            PODA O CORTE DE ARBOLES
# 1          REDUCCIÓN DEL RIESGO            PODA O CORTE DE ARBOLES
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1858 entries, 0 to 1857
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   FECHA DE INICIO                       1858 non-null   object
#  1   FECHA FINAL                           1858 non-null   object
#  2   DEPARTAMENTO                          1858 non-null   object
#  3   MUNICIPIO                             1858 non-null   object
#  4   FUERZA O ENTIDAD                      1858 non-null   object
#  5   ENTIDAD VINCULADA                     1740 non-null   object
#  6   PROCESO DE GESTIÓN DEL RIESGO         1858 non-null   object
#  7   ACTIVIDAD REALIZADA                   1858 non-null   object
#  8   MEDIOS EQUIPOS/PLATAFORMAS EMPLEADOS  1856 non-null   object
#  9   CANTIDAD DE MEDIOS EMPLEADOS          1856 non-null   float64
#  10  PERSONAL EMPLEADO                     1858 non-null   int64
# ...

# %%
df.describe()
# Out:
#        CANTIDAD DE MEDIOS EMPLEADOS  PERSONAL EMPLEADO
# count                   1856.000000        1858.000000
# mean                       1.096983          12.181916
# std                        0.603915          10.205759
# min                        0.000000           1.000000
# 25%                        1.000000           6.000000
# 50%                        1.000000          11.000000
# 75%                        1.000000          14.000000
# max                        9.000000         237.000000

# %%
df.columns
# Out:
# Index(['FECHA DE INICIO', 'FECHA FINAL', 'DEPARTAMENTO', 'MUNICIPIO',
#        'FUERZA O ENTIDAD', 'ENTIDAD VINCULADA',
#        'PROCESO DE GESTIÓN DEL RIESGO', 'ACTIVIDAD REALIZADA',
#        'MEDIOS EQUIPOS/PLATAFORMAS EMPLEADOS', 'CANTIDAD DE MEDIOS EMPLEADOS',
#        'PERSONAL EMPLEADO'],
#       dtype='object')

# %%
df["DEPARTAMENTO"]
# Out:
# 0                                         VALLE DEL CAUCA
# 1                                            CUNDINAMARCA
# 2                                               ANTIOQUIA
# 3                                         VALLE DEL CAUCA
# 4                                               SANTANDER
#                               ...
# 1853                                                SUCRE
# 1854                                                SUCRE
# 1855                                              CÓRDOBA
# 1856    ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANT...
# 1857                                              CAQUETÁ
# Name: DEPARTAMENTO, Length: 1858, dtype: object

# %%
df[["PERSONAL EMPLEADO","ENTIDAD VINCULADA"]]
# Out:
#       PERSONAL EMPLEADO    ENTIDAD VINCULADA
# 0                    23  ENTIDADES DEL SNGRD
# 1                    32  ENTIDADES DEL SNGRD
# 2                    22  ENTIDADES DEL SNGRD
# 3                    23  ENTIDADES DEL SNGRD
# 4                    12  ENTIDADES DEL SNGRD
# ...                 ...                  ...
# 1853                  2                  NaN
# 1854                  2                  NaN
# 1855                  2                  NaN
# 1856                  3             GOBIERNO
# 1857                  4             GOBIERNO
#
# [1858 rows x 2 columns]

# %%
df.iloc[17]
# Out:
# FECHA DE INICIO                         2024 Jan 10 12:00:00 AM
# FECHA FINAL                             2024 Jan 11 12:00:00 AM
# DEPARTAMENTO                                       CUNDINAMARCA
# MUNICIPIO                                                BOGOTÁ
# FUERZA O ENTIDAD                              EJÉRCITO NACIONAL
# ENTIDAD VINCULADA                           ENTIDADES DEL SNGRD
# PROCESO DE GESTIÓN DEL RIESGO              REDUCCIÓN DEL RIESGO
# ACTIVIDAD REALIZADA                     PODA O CORTE DE ARBOLES
# MEDIOS EQUIPOS/PLATAFORMAS EMPLEADOS                 MOTOSIERRA
# CANTIDAD DE MEDIOS EMPLEADOS                                1.0
# PERSONAL EMPLEADO                                            30
# Name: 17, dtype: object

# %%
df[df["PERSONAL EMPLEADO"]>20]
# Out:
#               FECHA DE INICIO              FECHA FINAL     DEPARTAMENTO  \
# 0     2024 Jan 01 12:00:00 AM  2024 Jan 01 12:00:00 AM  VALLE DEL CAUCA
# 1     2024 Jan 01 12:00:00 AM  2024 Jan 02 12:00:00 AM     CUNDINAMARCA
# 2     2024 Jan 01 12:00:00 AM  2024 Jan 03 12:00:00 AM        ANTIOQUIA
# 3     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM  VALLE DEL CAUCA
# 8     2024 Jan 03 12:00:00 AM  2024 Jan 09 12:00:00 AM            HUILA
# ...                       ...                      ...              ...
# 1828  2024 Dec 02 12:00:00 AM  2024 Dec 02 12:00:00 AM       LA GUAJIRA
# 1835  2024 Dec 04 12:00:00 AM  2024 Dec 04 12:00:00 AM        MAGDALENA
# 1842  2024 Dec 06 12:00:00 AM  2024 Dec 06 12:00:00 AM        ATLÁNTICO
# 1845  2024 Dec 08 12:00:00 AM  2024 Dec 08 12:00:00 AM            CHOCÓ
# 1851  2024 Dec 10 12:00:00 AM  2024 Dec 10 12:00:00 AM            CHOCÓ
#
#               MUNICIPIO             FUERZA O ENTIDAD  \
# ...

# %%
df[(df["PERSONAL EMPLEADO"]) <20 / (df["DEPARTAMENTO"]=="HUILA")]
# Out:
#               FECHA DE INICIO              FECHA FINAL  \
# 0     2024 Jan 01 12:00:00 AM  2024 Jan 01 12:00:00 AM
# 1     2024 Jan 01 12:00:00 AM  2024 Jan 02 12:00:00 AM
# 2     2024 Jan 01 12:00:00 AM  2024 Jan 03 12:00:00 AM
# 3     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM
# 4     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM
# ...                       ...                      ...
# 1853  2024 Dec 12 12:00:00 AM  2024 Dec 12 12:00:00 AM
# 1854  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1855  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1856  2024 Dec 25 12:00:00 AM  2024 Dec 25 12:00:00 AM
# 1857  2024 Dec 30 12:00:00 AM  2024 Dec 30 12:00:00 AM
#
#                                            DEPARTAMENTO            MUNICIPIO  \
# 0                                       VALLE DEL CAUCA                 CALI
# 1                                          CUNDINAMARCA                 NILO
# ...

# %%
df.columns
# Out:
# Index(['FECHA DE INICIO', 'FECHA FINAL', 'DEPARTAMENTO', 'MUNICIPIO',
#        'FUERZA O ENTIDAD', 'ENTIDAD VINCULADA',
#        'PROCESO DE GESTIÓN DEL RIESGO', 'ACTIVIDAD REALIZADA',
#        'MEDIOS EQUIPOS/PLATAFORMAS EMPLEADOS', 'CANTIDAD DE MEDIOS EMPLEADOS',
#        'PERSONAL EMPLEADO'],
#       dtype='object')

# %%
df["PERSONAL EMPLEADO 22"] = df["PERSONAL EMPLEADO"] * 2
df["PERSONAL EMPLEADO 22"]
# Out:
# 0       46
# 1       64
# 2       44
# 3       46
# 4       24
#         ..
# 1853     4
# 1854     4
# 1855     4
# 1856     6
# 1857     8
# Name: PERSONAL EMPLEADO 22, Length: 1858, dtype: int64

# %%
df.sort_values(by="PERSONAL EMPLEADO")
# Out:
#               FECHA DE INICIO              FECHA FINAL        DEPARTAMENTO  \
# 575   2024 Mar 20 12:00:00 AM  2024 Mar 21 12:00:00 AM              TOLIMA
# 531   2024 Mar 17 12:00:00 AM  2024 Mar 18 12:00:00 AM        CUNDINAMARCA
# 613   2024 Mar 25 12:00:00 AM  2024 Mar 25 12:00:00 AM              BOYACÁ
# 600   2024 Mar 22 12:00:00 AM  2024 Mar 24 12:00:00 AM              TOLIMA
# 437   2024 Mar 08 12:00:00 AM  2024 Mar 08 12:00:00 AM        CUNDINAMARCA
# ...                       ...                      ...                 ...
# 287   2024 Feb 23 12:00:00 AM  2024 Feb 26 12:00:00 AM             VICHADA
# 1076  2024 Jun 26 12:00:00 AM  2024 Jun 26 12:00:00 AM        CUNDINAMARCA
# 271   2024 Feb 21 12:00:00 AM  2024 Feb 21 12:00:00 AM        CUNDINAMARCA
# 77    2024 Jan 24 12:00:00 AM  2024 Jan 27 12:00:00 AM  NORTE DE SANTANDER
# 1569  2024 Oct 02 12:00:00 AM  2024 Oct 02 12:00:00 AM               CESAR
#
#               MUNICIPIO   FUERZA O ENTIDAD    ENTIDAD VINCULADA  \
# ...

# %%
df.isnull().sum()
df.fillna(0)
# Out:
#               FECHA DE INICIO              FECHA FINAL  \
# 0     2024 Jan 01 12:00:00 AM  2024 Jan 01 12:00:00 AM
# 1     2024 Jan 01 12:00:00 AM  2024 Jan 02 12:00:00 AM
# 2     2024 Jan 01 12:00:00 AM  2024 Jan 03 12:00:00 AM
# 3     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM
# 4     2024 Jan 02 12:00:00 AM  2024 Jan 02 12:00:00 AM
# ...                       ...                      ...
# 1853  2024 Dec 12 12:00:00 AM  2024 Dec 12 12:00:00 AM
# 1854  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1855  2024 Dec 18 12:00:00 AM  2024 Dec 18 12:00:00 AM
# 1856  2024 Dec 25 12:00:00 AM  2024 Dec 25 12:00:00 AM
# 1857  2024 Dec 30 12:00:00 AM  2024 Dec 30 12:00:00 AM
#
#                                            DEPARTAMENTO            MUNICIPIO  \
# 0                                       VALLE DEL CAUCA                 CALI
# 1                                          CUNDINAMARCA                 NILO
# ...
